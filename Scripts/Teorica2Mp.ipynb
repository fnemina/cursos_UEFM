# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import patches
plt.rcParams.update({'font.size': 18})
import matplotlib
matplotlib.font_manager._rebuild()

# %%
plt.rcParams['axes.facecolor']='#ffffff'
plt.rcParams['savefig.facecolor']='#ffffff'
plt.rcParams.update({'font.size': 18})

fig = plt.figure(figsize=(8,4.5))
x = np.linspace(0,1)
ax1 = fig.add_subplot(111)
ellipse = patches.Arc(xy=(0.5, 0.5),width=0.8, height=0.2, 
                        edgecolor='k', fc='w', lw=3,  theta1=145, theta2=35.0, ls=':',alpha=0.5)
ax1.add_patch(ellipse)
ax1.text(0.5,0.25,s='🌎',horizontalalignment='center',
         verticalalignment='bottom',fontsize=160,fontname="Twitter Color Emoji")
ax1.text(.05,0.51,s='🛰️',horizontalalignment='center',
         verticalalignment='center',fontsize=50,fontname="Twitter Color Emoji", rotation=45)
plt.yticks([], [])
plt.xticks([], [])
plt.tight_layout()
ax1.axis('off')
plt.savefig("fig:geo.png",dpi=300,transparent=True)
plt.show()

# %%
plt.rcParams['axes.facecolor']='#ffffff'
plt.rcParams['savefig.facecolor']='#ffffff'
plt.rcParams.update({'font.size': 18})

fig = plt.figure(figsize=(8,4.5))
x = np.linspace(0,1)
ax1 = fig.add_subplot(111)
ellipse = patches.Arc(xy=(0.5, 0.5),width=0.9, height=0.1, 
                        edgecolor='k', fc='w', lw=3,  theta1=-7, theta2=190.0, ls=':',alpha=0.5, angle=80)
ax1.add_patch(ellipse)
ax1.text(0.5,0.25,s='🌎',horizontalalignment='center',
         verticalalignment='bottom',fontsize=160,fontname="Twitter Color Emoji")
ax1.text(.59,1,s='🛰️',horizontalalignment='center',
         verticalalignment='center',fontsize=50,fontname="Twitter Color Emoji", rotation=-65)
plt.yticks([], [])
plt.xticks([], [])
ax1.axis('off')
plt.tight_layout()
plt.savefig("fig:pol.png",dpi=300,transparent=True)
plt.show()

# %%
plt.rcParams['axes.facecolor']='#ffffff'
plt.rcParams['savefig.facecolor']='#ffffff'
plt.rcParams.update({'font.size': 18})

fig = plt.figure(figsize=(8,4.5))
x = np.linspace(0,1)
ax1 = fig.add_subplot(111)
ellipse = patches.Arc(xy=(0.5, 0.5),width=0.9, height=0.1, 
                        edgecolor='k', fc='w', lw=3,  theta1=-7, theta2=190.0, ls=':',alpha=0.5, angle=80)
ax1.add_patch(ellipse)
ax1.text(0.5,0.25,s='🌎',horizontalalignment='center',
         verticalalignment='bottom',fontsize=160,fontname="Twitter Color Emoji")
ax1.text(.59,1,s='🛰️',horizontalalignment='center',
         verticalalignment='center',fontsize=50,fontname="Twitter Color Emoji", rotation=-65)
plt.yticks([], [])
plt.xticks([], [])
ax1.axis('off')
plt.tight_layout()
plt.savefig("fig:pol.png",dpi=300,transparent=True)
plt.show()

# %%
plt.rcParams['axes.facecolor']='#ffffff'
plt.rcParams['savefig.facecolor']='#ffffff'
plt.rcParams.update({'font.size': 18})

fig = plt.figure(figsize=(8,4.5))
x = np.linspace(0,1)
ax1 = fig.add_subplot(111)

ax1.text(.75,.9,s='🛰️',horizontalalignment='center',
         verticalalignment='center',fontsize=50,fontname="Twitter Color Emoji", rotation=-45)
plt.yticks([], [])
plt.xticks([], [])
ax1.text(0.6,0.02,s='🏠🏠🏠🌳    🏠🌳🌳🌳',horizontalalignment='left',verticalalignment='bottom',
         fontsize=20,fontname="Twitter Color Emoji")
ax1.text(0.3,0.02,s='📡',horizontalalignment='left',verticalalignment='bottom',
         fontsize=50,fontname="Twitter Color Emoji" )

ax1.text(0.08,0.5,s='🖼️',horizontalalignment='left',verticalalignment='bottom',
         fontsize=70,fontname="Twitter Color Emoji" )

ax1.annotate("", xy=(0.75, 0.75), xytext=(0.75, 0.15),arrowprops=dict(arrowstyle="->",alpha=1,lw=5,color='k'))
ax1.annotate("", xy=(0.37, 0.17), xytext=(0.70, 0.75),arrowprops=dict(arrowstyle="->",alpha=1,lw=5,color='k'))
ax1.annotate("", xy=(0.15, 0.1), xytext=(0.30, 0.1),arrowprops=dict(arrowstyle="-",alpha=1,lw=5,color='k'))
ax1.annotate("", xy=(0.15, 0.5), xytext=(0.15, 0.1),arrowprops=dict(arrowstyle="->",alpha=1,lw=5,color='k'))

ax1.axis('off')
plt.tight_layout()
plt.savefig("fig:esquema.png",dpi=300,transparent=True)
plt.show()

# %%
plt.rcParams['axes.facecolor']='#ffffff'
plt.rcParams['savefig.facecolor']='#ffffff'

plt.rcParams.update({'font.size': 18})

fig = plt.figure(figsize=(8,4.5))
x = np.linspace(0,1)
ax1 = fig.add_subplot(111)


ax1.text(0.87,0.8,s='🛰️',horizontalalignment='center',verticalalignment='center',fontsize=70,fontname="Twitter Color Emoji",rotation=-90)
ax1.text(0.5,0.1,s='🌲🌲🏡🌲🌳🌳',horizontalalignment='center',verticalalignment='center',fontsize=40,fontname="Twitter Color Emoji")
ax1.text(0.16,0.8,s='☀️',horizontalalignment='center',verticalalignment='center',fontsize=80,fontname="Twitter Color Emoji")

ax1.annotate("", xy=(0.45, 0.2), xytext=(0.22, 0.67),arrowprops=dict(arrowstyle="->",alpha=1,lw=5,color='k'))
ax1.annotate("", xy=(0.8, 0.67), xytext=(0.55, 0.2),arrowprops=dict(arrowstyle="->",alpha=1,lw=5,color='k'))

plt.yticks([], [])
plt.xticks([], [])

plt.tight_layout()
ax1.axis('off')
plt.savefig("fig:pasivo.png",dpi=300,transparent=False)
plt.show()

# %%
plt.rcParams['axes.facecolor']='#ffffff'
plt.rcParams['savefig.facecolor']='#ffffff'

plt.rcParams.update({'font.size': 18})

fig = plt.figure(figsize=(8,4.5))
x = np.linspace(0,1)
ax1 = fig.add_subplot(111)


ax1.text(0.85,0.8,s='🛰️',horizontalalignment='center',verticalalignment='center',fontsize=70,fontname="Twitter Color Emoji",rotation=-90)
ax1.text(0.5,0.1,s='🌲🌲🏡🌲🌳🌳',horizontalalignment='center',verticalalignment='center',fontsize=40,fontname="Twitter Color Emoji")

ax1.annotate("", xy=(0.51, 0.23), xytext=(0.76, 0.70),arrowprops=dict(arrowstyle="->",alpha=1,lw=5,color='k'))
ax1.annotate("", xy=(0.8, 0.65), xytext=(0.55, 0.18),arrowprops=dict(arrowstyle="->",alpha=1,lw=5,color='k'))

plt.yticks([], [])
plt.xticks([], [])

plt.tight_layout()
ax1.axis('off')
plt.savefig("fig:activo.png",dpi=300,transparent=False)
plt.show()

# %%
plt.rcParams.update({'font.size': 18})
fig = plt.figure(figsize=(16,9))
ax1 = fig.add_subplot(111)

x = np.linspace(0.5,0.78)
y = 3*(0.5-x)+0.85
z = 3*(0.5-x)+0.85

plt.plot(1-x,y,'k--',alpha=0.3)
plt.plot(x,z,'k--',alpha=0.3)

x = np.linspace(0.5,0.652)
y = 5.5*(0.5-x)+0.85
z = 8.5*(0.5-x)+0.85

plt.plot(x,y,'k--',alpha=0.7)
x = np.linspace(0.5,0.6)
z = 8.5*(0.5-x)+0.85
plt.plot(x,z,'k--',alpha=0.7)

ax1.text(0.5,0.85,s='🛰️',horizontalalignment='center',verticalalignment='center',fontsize=70,fontname="Twitter Color Emoji", rotation=-30)

ax1.axes.add_patch(patches.Rectangle((0.,0), 1, 0.02,facecolor="black"))
ax1.axes.add_patch(patches.Rectangle((0.22,0), 0.56, 0.02,facecolor="lightgrey"))
ax1.axes.add_patch(patches.Rectangle((0.60,0), 0.055, 0.02,facecolor="grey"))
ax1.axes.add_patch(patches.Wedge((0.5, 0.85), 0.2, -83, -79, width=0.010,color='lightgrey'), )

ax1.text(0.63,-0.05,s='Pixel',horizontalalignment='center',verticalalignment='center')
ax1.text(0.49,0.66,s='iFOV',horizontalalignment='center',verticalalignment='center')
ax1.axes.add_patch(patches.Rectangle((0.,-0.1), 1, 0.1,facecolor="#fafafa",fill=True,alpha=1))
ax1.text(0.50,-0.05,s='Ancho de barrido',horizontalalignment='center',verticalalignment='center')

ax1.axes.add_patch(patches.Wedge((0.5, 0.85), 0.5, -108, -72, width=0.010,color='lightgrey'), )
ax1.text(0.50,0.3,s='FOV',horizontalalignment='center',verticalalignment='center')
# Configuracion ejes
plt.ylim(-.1,1)
plt.yticks([])
plt.xticks([])

plt.xlim(0,1)
plt.tight_layout()
ax1.axis('off')
plt.savefig("fig:ifov.png",dpi=300,transparent=True)
plt.show()

# %%
### plt.rcParams['axes.facecolor']='#ffffff'
plt.rcParams['savefig.facecolor']='#ffffff'
plt.rcParams.update({'font.size': 18})

im = plt.imread('im.jpg')

fig = plt.figure(figsize=(12,4.5))


newax = fig.add_axes([-0.2, 0.1, 0.8, 0.8], anchor='C', zorder=0)
newax.imshow(im)
newax.axis('off')

# Create a Rectangle patch
rect = patches.Rectangle((165,180),40,40,linewidth=1,edgecolor='r',facecolor='none', lw=3)

# Add the patch to the Axes
newax.add_patch(rect)

imagen = np.copy(im[165:185,180:200])[:,:,0]

newaxr = fig.add_axes([0.45, 0.40, 0.5, 0.5], anchor='C', zorder=0)
newaxr.imshow(imagen, 'Greys', vmin=0, vmax=200)
newaxr.axis('off')

imagen = np.copy(im[165:185,180:200])[:,:,2]

newaxr = fig.add_axes([0.40, 0.30, 0.5, 0.5], anchor='C', zorder=0)
newaxr.imshow(imagen, 'Greys', vmin=0, vmax=200)
newaxr.axis('off')

imagen = np.copy(im[165:185,180:200])[:,:,1]

newaxg = fig.add_axes([0.35, 0.20, 0.5, 0.5], anchor='C', zorder=0)
newaxg.imshow(imagen, 'Greys', vmin=0, vmax=200)
newaxg.axis('off')



ax1 = fig.add_subplot(111,zorder=1)
ax1.axis('off')
coordsA = "data"
coordsB = "data"
con1 = patches.ConnectionPatch((0.107,0.628), (0.455, 0.028), coordsA, coordsB,
                      arrowstyle="-", shrinkA=5, shrinkB=5,
                      mutation_scale=20, fc="w", ec='r', lw=2)
con2 = patches.ConnectionPatch((0.128,0.628), (0.455+0.202, 0.028), coordsA, coordsB,
                      arrowstyle="-", shrinkA=5, shrinkB=5,
                      mutation_scale=20, fc="w", ec='r', lw=2)
con3 = patches.ConnectionPatch((0.128,0.685), (0.455+0.202, 0.028+0.595), coordsA, coordsB,
                      arrowstyle="-", shrinkA=5, shrinkB=5,
                      mutation_scale=20, fc="w", ec='r', lw=2)
con4 = patches.ConnectionPatch((0.107,0.685), (0.455, 0.028+0.595), coordsA, coordsB,
                      arrowstyle="-", shrinkA=5, shrinkB=5,
                      mutation_scale=20, fc="w", ec='r', lw=2)
rect2 = patches.Rectangle((0.451,0.033),0.203,0.591,linewidth=1,edgecolor='r',facecolor='none', lw=3)
ax1.add_artist(con1)
ax1.add_artist(con2)
ax1.add_artist(con3)
ax1.add_artist(con4)
ax1.add_artist(rect2)


arr1 = patches.ConnectionPatch((0.66,0.16), (0.92, 0.16), coordsA, coordsB,
                      arrowstyle="-|>", shrinkA=5, shrinkB=5,
                      mutation_scale=40, fc="w", ec='b', lw=4)
ax1.add_artist(arr1)
arr2 = patches.ConnectionPatch((0.71,0.36), (0.92, 0.36), coordsA, coordsB,
                      arrowstyle="-|>", shrinkA=5, shrinkB=5,
                      mutation_scale=40, fc="w", ec='g', lw=4)
ax1.add_artist(arr2)

arr3 = patches.ConnectionPatch((0.76,0.66), (0.92, 0.66), coordsA, coordsB,
                      arrowstyle="-|>", shrinkA=5, shrinkB=5,
                      mutation_scale=40, fc="w", ec='r', lw=4)
ax1.add_artist(arr3)

arr4 = patches.ConnectionPatch((0.81,0.86), (0.92, 0.86), coordsA, coordsB,
                      arrowstyle="-|>", shrinkA=5, shrinkB=5,
                      mutation_scale=40, fc="w", ec='grey', lw=4)
ax1.add_artist(arr4)

imagen = np.copy(im[165:185,180:200])[:,:,0]
newaxb = fig.add_axes([0.30, 0.10, 0.5, 0.5], anchor='C', zorder=2)
newaxb.imshow(imagen, 'Greys', vmin=0, vmax=200)
newaxb.axis('off')

rainbow = fig.add_axes([0.83, 0.1, 0.2, 0.8], anchor='C', zorder=0)
color = np.zeros([300,40])
for i in range(40):
    color[:,i]= np.linspace(255,0,300)
color[color>255] = 255
rainbow.imshow(color,'nipy_spectral', vmax=200)
rainbow.axis('off')
plt.savefig("fig:bandas.png",dpi=300,transparent=True)
plt.show()

# %%
### plt.rcParams['axes.facecolor']='#ffffff'
plt.rcParams['savefig.facecolor']='#ffffff'
plt.rcParams.update({'font.size': 18})

im8 = plt.imread('8.jpg')
im4 = plt.imread('4.jpg')
im2 = plt.imread('2.jpg')
im1 = plt.imread('1.jpg')

fig = plt.figure(figsize=(12,4.5))

newax8 = fig.add_axes([-0.2, 0.1, 0.8, 0.8], anchor='C', zorder=1)
newax8.imshow(im8, 'Greys')
newax8.axis('off')

newax4 = fig.add_axes([0.15, 0.1, 0.8, 0.8], anchor='C', zorder=1)
newax4.imshow(im4, 'Greys')
newax4.axis('off')

colors = [  'Blues', 'Greens', 'Oranges', 'Reds']


newax2.text(300,650,s='Pancromatica',horizontalalignment='center',verticalalignment='center')
newax2.text(1000,650,s='Multiespectral',horizontalalignment='center',verticalalignment='center')


plt.savefig("fig:panmulti.png",dpi=300,transparent=True)
plt.show()
